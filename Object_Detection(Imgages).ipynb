# %% [markdown]
# <a href="https://colab.research.google.com/github/BarkathNisha020105/object-detection-using-images/blob/main/Object_Detection(Imgages).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow opencv-python matplotlib

# %%
import tensorflow as tf
import tensorflow_hub as hub
import cv2
import matplotlib.pyplot as plt

# %%
# !pip install torch torchvision

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# /content/yolov5
# ...

# %%
# !wget https://ultralytics.com/images/zidane.jpg -O test_image.jpg
# Out:
# --2025-08-18 18:28:05--  https://ultralytics.com/images/zidane.jpg
# Resolving ultralytics.com (ultralytics.com)... 75.2.70.75, 99.83.190.102
# Connecting to ultralytics.com (ultralytics.com)|75.2.70.75|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.ultralytics.com/images/zidane.jpg [following]
# --2025-08-18 18:28:06--  https://www.ultralytics.com/images/zidane.jpg
# Resolving www.ultralytics.com (www.ultralytics.com)... 104.18.40.102, 172.64.147.154, 2606:4700:4400::6812:2866, ...
# Connecting to www.ultralytics.com (www.ultralytics.com)|104.18.40.102|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://github.com/ultralytics/assets/releases/download/v0.0.0/zidane.jpg [following]
# --2025-08-18 18:28:06--  https://github.com/ultralytics/assets/releases/download/v0.0.0/zidane.jpg
# Resolving github.com (github.com)... 20.205.243.166
# ...

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source test_image.jpg
# Out:
# detect: weights=['yolov5s.pt'], source=test_image.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-425-g85acef3a Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# image 1/1 /content/yolov5/test_image.jpg: 384x640 2 persons, 1 tie, 1 cell phone, 30.3ms
# Speed: 0.5ms pre-process, 30.3ms inference, 128.3ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp5

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b07a6164-7269-4b38-b9a9-969c0fdc5023" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b07a6164-7269-4b38-b9a9-969c0fdc5023">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !ls runs/detect/
# !ls runs/detect/exp/
# Out:
# exp  exp2  exp3  exp4  exp5
# test_image.jpg

# %%
import cv2
from google.colab.patches import cv2_imshow

# Load and display the output image
output_image = cv2.imread('runs/detect/exp/test_image.jpg')
cv2_imshow(output_image)  # Colab-compatible alternative to cv2.imshow()
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720>

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source dogs.jpg
# Out:
# detect: weights=['yolov5s.pt'], source=dogs.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-425-g85acef3a Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# image 1/1 /content/yolov5/dogs.jpg: 640x640 1 dog, 12.8ms
# Speed: 0.6ms pre-process, 12.8ms inference, 153.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp6

# %%
output_image = cv2.imread('runs/detect/exp6/dogs.jpg')
cv2_imshow(output_image)
# Out:
# <PIL.Image.Image image mode=RGB size=980x977>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ac4470db-4df7-40f5-92f8-95fbadd8a5ae" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ac4470db-4df7-40f5-92f8-95fbadd8a5ae">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source cat3.jpg
# Out:
# detect: weights=['yolov5s.pt'], source=cat3.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-425-g85acef3a Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# image 1/1 /content/yolov5/cat3.jpg: 640x576 1 cat, 28.8ms
# Speed: 0.5ms pre-process, 28.8ms inference, 123.7ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp8

# %%
output_image = cv2.imread('runs/detect/exp8/cat3.jpg')
cv2_imshow(output_image)
# Out:
# <PIL.Image.Image image mode=RGB size=761x880>
